# %% [markdown]
# <a href="https://colab.research.google.com/github/agmalaga2020/PolicySpace2_Spanish_data/blob/main/estimativas_pop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INICIO
#
# - 1º buscamos fuente a explorar
# https://uoc0-my.sharepoint.com/:x:/g/personal/agmalaga_uoc_edu/EVrtEuZkGqxMsXz3ENcmP8sB8w9sxyyFWBX3pDP282BDaQ?e=hZX8jz
#
# _______________________________________________________________
#
# - 2º `CARGAMOS` DATAFRAME ORIGINAL del proyecto **github**
# https://github.com/agmalaga2020/PolicySpace2-agmalaga/tree/master/input
#
# _______________________________________________________________
# - 3º Realizamos analisis exploratorio en google colab.
# _______________________________________________________________
#
# - 4º descargamos datos y creamos informe.
# _______________________________________________________________
#
# - 5º actualizar LINK de la columna `NOTEBOOK`
# https://uoc0-my.sharepoint.com/:x:/g/personal/agmalaga_uoc_edu/EVrtEuZkGqxMsXz3ENcmP8sB8w9sxyyFWBX3pDP282BDaQ?e=hZX8jz
#
# _______________________________________________________________
#
# ESQUEMA DE PROCESO
#
# https://whiteboard.office.com/me/whiteboards/p/c3BvOmh0dHBzOi8vdW9jMC1teS5zaGFyZXBvaW50LmNvbS9wZXJzb25hbC9hZ21hbGFnYV91b2NfZWR1/b!r4X97qYbxUyQGQNSpn-bfrNi376yDThFsrR2Kul1sxTx_nU34TfBSpdz-6pNWzvq/01E765GIPQJMS23ADWVBEID5XGUDPDSQNZ?source=applauncher&auth_upn=agmalaga%40uoc.edu

# %% [markdown]
# ### average_num_members_families_2010

# %%
import requests
import pandas as pd
import io

# Update the URL to point to the raw CSV data on GitHub
url = 'https://raw.githubusercontent.com/BAFurtado/PolicySpace2/master/input/estimativas_pop.csv'
s = requests.get(url).content
df = pd.read_csv(io.StringIO(s.decode('utf-8')))
print(df.head())
# Out:
#    mun_code       2001       2002       2003       2004       2005       2006  \
# 0   1302603  1451958.0  1488805.0  1527314.0  1592555.0  1644690.0  1688524.0
# 1   1500800   410234.0   423325.0   437135.0   468463.0   482171.0   498095.0
# 2   1501303    65385.0    66913.0    68604.0    72441.0    74120.0    76071.0
# 3   1501402  1304314.0  1322683.0  1342202.0  1386482.0  1405871.0  1428368.0
# 4   1501501    37025.0    38458.0    39809.0    42874.0    44216.0    45774.0
#
#         2008       2009       2011     2012     2013     2014     2015  \
# 0  1709008.0  1738641.0  1832424.0  1861838  1982177  2020301  2057711
# 1   495480.0   505512.0   477999.0   483821   493976   499776   505404
# 2    89909.0    92567.0   102668.0   105385   109975   112921   115779
# 3  1424120.0  1437600.0  1402056.0  1410430  1425922  1432844  1439561
# 4    45616.0    46611.0    52888.0    54083    56112    57393    58637
#
#       2016     2017     2018     2019
# 0  2094391  2130264  2145444  2182763
# 1   510834   516057   525566   530598
# 2   118537   121190   122294   124680
# 3  1446042  1452275  1485732  1492745
# 4    59836    60990    61689    62737

# %% [markdown]
# # ESPAÑA
#
# tenemos que extraer tabla a tabla por municipio para finalmente transformar los datos para conseeguir el mismo resultado.

# %% [markdown]
# ### Cifras de Población por Municipio
#
# https://www.ine.es/dynt3/inebase/es/index.htm?padre=525

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de la página de detalle municipal del INE
url = "https://www.ine.es/dynt3/inebase/es/index.htm?padre=525"
response = requests.get(url)
response.encoding = 'utf-8'  # Aseguramos la codificación
soup = BeautifulSoup(response.text, 'html.parser')

data = []
# Buscamos todos los enlaces que contengan "Población por municipios y sexo" en el texto
for a in soup.find_all('a'):
    text = a.get_text(strip=True)
    if "Población por municipios y sexo" in text:
        # Se asume que el nombre del municipio o entidad es la parte anterior al colon
        nombre = text.split(":")[0].strip()
        enlace = a.get('href')
        if enlace and not enlace.startswith("http"):
            # Convertir a URL absoluta si es relativa
            enlace = "https://www.ine.es" + enlace
        data.append({"Municipio": nombre, "Enlace": enlace})

# Crear un DataFrame de Pandas con los resultados
df = pd.DataFrame(data)
df.head()
# Out:
#           Municipio                                          Enlace
# 0          Albacete  https://www.ine.es/jaxiT3/Tabla.htm?t=2855&L=0
# 1  Alicante/Alacant  https://www.ine.es/jaxiT3/Tabla.htm?t=2856&L=0
# 2           Almería  https://www.ine.es/jaxiT3/Tabla.htm?t=2857&L=0
# 3       Araba/Álava  https://www.ine.es/jaxiT3/Tabla.htm?t=2854&L=0
# 4          Asturias  https://www.ine.es/jaxiT3/Tabla.htm?t=2886&L=0

# %% [markdown]
# ### creamos variable table_code

# %%
import pandas as pd

# Supongamos que ya tienes el DataFrame df con las columnas "Municipio" y "Enlace"
# Creamos una nueva columna "table_code" extrayendo el número que aparece tras "t="

df['table_code'] = df['Enlace'].str.extract(r't=(\d+)')

df.head()
# Out:
#           Municipio                                          Enlace table_code
# 0          Albacete  https://www.ine.es/jaxiT3/Tabla.htm?t=2855&L=0       2855
# 1  Alicante/Alacant  https://www.ine.es/jaxiT3/Tabla.htm?t=2856&L=0       2856
# 2           Almería  https://www.ine.es/jaxiT3/Tabla.htm?t=2857&L=0       2857
# 3       Araba/Álava  https://www.ine.es/jaxiT3/Tabla.htm?t=2854&L=0       2854
# 4          Asturias  https://www.ine.es/jaxiT3/Tabla.htm?t=2886&L=0       2886

# %% [markdown]
# ### extraemos las tablas

# %%
import requests
import pandas as pd

# Supongamos que ya tienes el DataFrame 'df' con la columna "table_code"
# Ejemplo de df:
#   Municipio           Enlace                                             table_code
# 0  Albacete  https://www.ine.es/jaxiT3/Tabla.htm?t=2855&L=0                    2855
# 1  Alicante/Alacant  https://www.ine.es/jaxiT3/Tabla.htm?t=2856&L=0                2856
# ...

for idx, code in df['table_code'].items():
    url_csv = f"https://servicios.ine.es/wstempus/csv/ES/DATOS_TABLA/{code}?nult=999"
    response = requests.get(url_csv)

    if response.status_code == 200:
        csv_data = response.content.decode('utf-8')
        filename = f"tabla_{code}.csv"

        with open(filename, "w", encoding="utf-8") as f:
            f.write(csv_data)
        print(f"Archivo CSV guardado como '{filename}' para table_code {code}")

        # Opcional: Leer y mostrar los primeros registros de la tabla
        tabla_df = pd.read_csv(filename, sep='\t', encoding='utf-8')
        print("Primeros registros de la tabla:")
        print(tabla_df.head())
        print("-" * 50)
    else:
        print(f"Error en la petición para table_code {code}: {response.status_code}")
# Out:
# Archivo CSV guardado como 'tabla_2855.csv' para table_code 2855
# Primeros registros de la tabla:
#         Municipios   Sexo  Periodo  Total
# 0  02001 Abengibre  Total     2024  759.0
# 1  02001 Abengibre  Total     2023  760.0
# 2  02001 Abengibre  Total     2022  739.0
# 3  02001 Abengibre  Total     2021  748.0
# 4  02001 Abengibre  Total     2020  761.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2856.csv' para table_code 2856
# Primeros registros de la tabla:
#     Municipios   Sexo  Periodo  Total
# 0  03002 Agost  Total     2024  5.107
# 1  03002 Agost  Total     2023  5.067
# 2  03002 Agost  Total     2022  4.948
# 3  03002 Agost  Total     2021  4.906
# 4  03002 Agost  Total     2020  4.794
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2857.csv' para table_code 2857
# Primeros registros de la tabla:
#    Municipios   Sexo  Periodo  Total
# 0  04001 Abla  Total     2024  1.272
# 1  04001 Abla  Total     2023  1.255
# 2  04001 Abla  Total     2022  1.247
# 3  04001 Abla  Total     2021  1.258
# 4  04001 Abla  Total     2020  1.248
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2854.csv' para table_code 2854
# Primeros registros de la tabla:
#                   Municipios   Sexo  Periodo  Total
# 0  01051 Agurain/Salvatierra  Total     2024  5.155
# 1  01051 Agurain/Salvatierra  Total     2023  5.085
# 2  01051 Agurain/Salvatierra  Total     2022  5.069
# 3  01051 Agurain/Salvatierra  Total     2021  5.029
# 4  01051 Agurain/Salvatierra  Total     2020  5.038
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2886.csv' para table_code 2886
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  33001 Allande  Total     2024  1.530
# 1  33001 Allande  Total     2023  1.552
# 2  33001 Allande  Total     2022  1.574
# 3  33001 Allande  Total     2021  1.620
# 4  33001 Allande  Total     2020  1.615
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2858.csv' para table_code 2858
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  05001 Adanero  Total     2024  208.0
# 1  05001 Adanero  Total     2023  204.0
# 2  05001 Adanero  Total     2022  214.0
# 3  05001 Adanero  Total     2021  196.0
# 4  05001 Adanero  Total     2020  211.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2859.csv' para table_code 2859
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  06001 Acedera  Total     2024  802.0
# 1  06001 Acedera  Total     2023  814.0
# 2  06001 Acedera  Total     2022  816.0
# 3  06001 Acedera  Total     2021  820.0
# 4  06001 Acedera  Total     2020  826.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2860.csv' para table_code 2860
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo   Total
# 0  07002 Alaior  Total     2024  10.042
# 1  07002 Alaior  Total     2023   9.748
# 2  07002 Alaior  Total     2022   9.606
# 3  07002 Alaior  Total     2021   9.477
# 4  07002 Alaior  Total     2020   9.467
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2861.csv' para table_code 2861
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo   Total
# 0  08001 Abrera  Total     2024  13.014
# 1  08001 Abrera  Total     2023  12.848
# 2  08001 Abrera  Total     2022  12.697
# 3  08001 Abrera  Total     2021  12.620
# 4  08001 Abrera  Total     2020  12.538
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2905.csv' para table_code 2905
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  48001 Abadiño  Total     2024  7.742
# 1  48001 Abadiño  Total     2023  7.708
# 2  48001 Abadiño  Total     2022  7.708
# 3  48001 Abadiño  Total     2021  7.618
# 4  48001 Abadiño  Total     2020  7.658
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2862.csv' para table_code 2862
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  09001 Abajas  Total     2024   28.0
# 1  09001 Abajas  Total     2023   28.0
# 2  09001 Abajas  Total     2022   29.0
# 3  09001 Abajas  Total     2021   29.0
# 4  09001 Abajas  Total     2020   31.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2863.csv' para table_code 2863
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  10001 Abadía  Total     2024  331.0
# 1  10001 Abadía  Total     2023  338.0
# 2  10001 Abadía  Total     2022  340.0
# 3  10001 Abadía  Total     2021  359.0
# 4  10001 Abadía  Total     2020  336.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2864.csv' para table_code 2864
# Primeros registros de la tabla:
#                     Municipios   Sexo  Periodo  Total
# 0  11001 Alcalá de los Gazules  Total     2024  5.223
# 1  11001 Alcalá de los Gazules  Total     2023  5.205
# 2  11001 Alcalá de los Gazules  Total     2022  5.227
# 3  11001 Alcalá de los Gazules  Total     2021  5.245
# 4  11001 Alcalá de los Gazules  Total     2020  5.226
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2893.csv' para table_code 2893
# Primeros registros de la tabla:
#                Municipios   Sexo  Periodo  Total
# 0  39001 Alfoz de Lloredo  Total     2024  2.499
# 1  39001 Alfoz de Lloredo  Total     2023  2.471
# 2  39001 Alfoz de Lloredo  Total     2022  2.466
# 3  39001 Alfoz de Lloredo  Total     2021  2.437
# 4  39001 Alfoz de Lloredo  Total     2020  2.394
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2865.csv' para table_code 2865
# Primeros registros de la tabla:
#          Municipios   Sexo  Periodo  Total
# 0  12003 Albocàsser  Total     2024  1.338
# 1  12003 Albocàsser  Total     2023  1.302
# 2  12003 Albocàsser  Total     2022  1.264
# 3  12003 Albocàsser  Total     2021  1.253
# 4  12003 Albocàsser  Total     2020  1.227
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2866.csv' para table_code 2866
# Primeros registros de la tabla:
#        Municipios   Sexo  Periodo  Total
# 0  13001 Abenójar  Total     2024  1.324
# 1  13001 Abenójar  Total     2023  1.328
# 2  13001 Abenójar  Total     2022  1.314
# 3  13001 Abenójar  Total     2021  1.339
# 4  13001 Abenójar  Total     2020  1.351
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2901.csv' para table_code 2901
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  14001 Adamuz  Total     2024  4.091
# 1  14001 Adamuz  Total     2023  4.092
# 2  14001 Adamuz  Total     2022  4.125
# 3  14001 Adamuz  Total     2021  4.141
# 4  14001 Adamuz  Total     2020  4.137
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2868.csv' para table_code 2868
# Primeros registros de la tabla:
#        Municipios   Sexo  Periodo  Total
# 0  15001 Abegondo  Total     2024  5.578
# 1  15001 Abegondo  Total     2023  5.584
# 2  15001 Abegondo  Total     2022  5.534
# 3  15001 Abegondo  Total     2021  5.494
# 4  15001 Abegondo  Total     2020  5.398
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2869.csv' para table_code 2869
# Primeros registros de la tabla:
#                    Municipios   Sexo  Periodo  Total
# 0  16001 Abia de la Obispalía  Total     2024   59.0
# 1  16001 Abia de la Obispalía  Total     2023   61.0
# 2  16001 Abia de la Obispalía  Total     2022   60.0
# 3  16001 Abia de la Obispalía  Total     2021   57.0
# 4  16001 Abia de la Obispalía  Total     2020   61.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2873.csv' para table_code 2873
# Primeros registros de la tabla:
#            Municipios   Sexo  Periodo  Total
# 0  20001 Abaltzisketa  Total     2024  319.0
# 1  20001 Abaltzisketa  Total     2023  326.0
# 2  20001 Abaltzisketa  Total     2022  309.0
# 3  20001 Abaltzisketa  Total     2021  312.0
# 4  20001 Abaltzisketa  Total     2020  318.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2870.csv' para table_code 2870
# Primeros registros de la tabla:
#        Municipios   Sexo  Periodo  Total
# 0  17001 Agullana  Total     2024  909.0
# 1  17001 Agullana  Total     2023  923.0
# 2  17001 Agullana  Total     2022  903.0
# 3  17001 Agullana  Total     2021  885.0
# 4  17001 Agullana  Total     2020  863.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2871.csv' para table_code 2871
# Primeros registros de la tabla:
#     Municipios   Sexo  Periodo  Total
# 0  18001 Agrón  Total     2024  244.0
# 1  18001 Agrón  Total     2023  239.0
# 2  18001 Agrón  Total     2022  247.0
# 3  18001 Agrón  Total     2021  255.0
# 4  18001 Agrón  Total     2020  260.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2872.csv' para table_code 2872
# Primeros registros de la tabla:
#        Municipios   Sexo  Periodo  Total
# 0  19002 Ablanque  Total     2024   73.0
# 1  19002 Ablanque  Total     2023   66.0
# 2  19002 Ablanque  Total     2022   63.0
# 3  19002 Ablanque  Total     2021   60.0
# 4  19002 Ablanque  Total     2020   55.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2874.csv' para table_code 2874
# Primeros registros de la tabla:
#         Municipios   Sexo  Periodo   Total
# 0  21002 Aljaraque  Total     2024  22.489
# 1  21002 Aljaraque  Total     2023  22.259
# 2  21002 Aljaraque  Total     2022  22.078
# 3  21002 Aljaraque  Total     2021  21.706
# 4  21002 Aljaraque  Total     2020  21.474
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2875.csv' para table_code 2875
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  22001 Abiego  Total     2024  264.0
# 1  22001 Abiego  Total     2023  261.0
# 2  22001 Abiego  Total     2022  278.0
# 3  22001 Abiego  Total     2021  271.0
# 4  22001 Abiego  Total     2020  258.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2876.csv' para table_code 2876
# Primeros registros de la tabla:
#                   Municipios   Sexo  Periodo    Total
# 0  23001 Albanchez de Mágina  Total     2024  930.000
# 1  23001 Albanchez de Mágina  Total     2023  958.000
# 2  23001 Albanchez de Mágina  Total     2022  993.000
# 3  23001 Albanchez de Mágina  Total     2021  992.000
# 4  23001 Albanchez de Mágina  Total     2020    1.011
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2877.csv' para table_code 2877
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  24001 Acebedo  Total     2024  184.0
# 1  24001 Acebedo  Total     2023  182.0
# 2  24001 Acebedo  Total     2022  185.0
# 3  24001 Acebedo  Total     2021  185.0
# 4  24001 Acebedo  Total     2020  184.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2878.csv' para table_code 2878
# Primeros registros de la tabla:
#                  Municipios   Sexo  Periodo  Total
# 0  25001 Abella de la Conca  Total     2024  158.0
# 1  25001 Abella de la Conca  Total     2023  167.0
# 2  25001 Abella de la Conca  Total     2022  167.0
# 3  25001 Abella de la Conca  Total     2021  171.0
# 4  25001 Abella de la Conca  Total     2020  183.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2880.csv' para table_code 2880
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  27001 Abadín  Total     2024  2.217
# 1  27001 Abadín  Total     2023  2.203
# 2  27001 Abadín  Total     2022  2.259
# 3  27001 Abadín  Total     2021  2.297
# 4  27001 Abadín  Total     2020  2.322
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2881.csv' para table_code 2881
# Primeros registros de la tabla:
#           Municipios   Sexo  Periodo Total
# 0  28001 Acebeda, La  Total     2024    68
# 1  28001 Acebeda, La  Total     2023    67
# 2  28001 Acebeda, La  Total     2022    62
# 3  28001 Acebeda, La  Total     2021    55
# 4  28001 Acebeda, La  Total     2020    68
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2882.csv' para table_code 2882
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  29001 Alameda  Total     2024  5.449
# 1  29001 Alameda  Total     2023  5.434
# 2  29001 Alameda  Total     2022  5.451
# 3  29001 Alameda  Total     2021  5.453
# 4  29001 Alameda  Total     2020  5.387
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2883.csv' para table_code 2883
# Primeros registros de la tabla:
#        Municipios   Sexo  Periodo  Total
# 0  30001 Abanilla  Total     2024  6.206
# 1  30001 Abanilla  Total     2023  6.216
# 2  30001 Abanilla  Total     2022  6.146
# 3  30001 Abanilla  Total     2021  6.116
# 4  30001 Abanilla  Total     2020  6.097
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2884.csv' para table_code 2884
# Primeros registros de la tabla:
#                          Municipios   Sexo  Periodo  Total
# 0  31003 Abaurregaina/Abaurrea Alta  Total     2024  119.0
# 1  31003 Abaurregaina/Abaurrea Alta  Total     2023  115.0
# 2  31003 Abaurregaina/Abaurrea Alta  Total     2022  120.0
# 3  31003 Abaurregaina/Abaurrea Alta  Total     2021  128.0
# 4  31003 Abaurregaina/Abaurrea Alta  Total     2020  127.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2885.csv' para table_code 2885
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  32001 Allariz  Total     2024  6.410
# 1  32001 Allariz  Total     2023  6.378
# 2  32001 Allariz  Total     2022  6.348
# 3  32001 Allariz  Total     2021  6.314
# 4  32001 Allariz  Total     2020  6.245
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2888.csv' para table_code 2888
# Primeros registros de la tabla:
#                Municipios   Sexo  Periodo  Total
# 0  34001 Abarca de Campos  Total     2024   38.0
# 1  34001 Abarca de Campos  Total     2023   42.0
# 2  34001 Abarca de Campos  Total     2022   43.0
# 3  34001 Abarca de Campos  Total     2021   45.0
# 4  34001 Abarca de Campos  Total     2020   45.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2889.csv' para table_code 2889
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  35001 Agaete  Total     2024  5.670
# 1  35001 Agaete  Total     2023  5.568
# 2  35001 Agaete  Total     2022  5.633
# 3  35001 Agaete  Total     2021  5.695
# 4  35001 Agaete  Total     2020  5.599
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2890.csv' para table_code 2890
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  36020 Agolada  Total     2024  2.282
# 1  36020 Agolada  Total     2023  2.254
# 2  36020 Agolada  Total     2022  2.252
# 3  36020 Agolada  Total     2021  2.228
# 4  36020 Agolada  Total     2020  2.304
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2879.csv' para table_code 2879
# Primeros registros de la tabla:
#         Municipios   Sexo  Periodo  Total
# 0  26002 Agoncillo  Total     2024  1.314
# 1  26002 Agoncillo  Total     2023  1.228
# 2  26002 Agoncillo  Total     2022  1.175
# 3  26002 Agoncillo  Total     2021  1.153
# 4  26002 Agoncillo  Total     2020  1.096
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2891.csv' para table_code 2891
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  37001 Abusejo  Total     2024  143.0
# 1  37001 Abusejo  Total     2023  150.0
# 2  37001 Abusejo  Total     2022  161.0
# 3  37001 Abusejo  Total     2021  166.0
# 4  37001 Abusejo  Total     2020  175.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2892.csv' para table_code 2892
# Primeros registros de la tabla:
#     Municipios   Sexo  Periodo   Total
# 0  38001 Adeje  Total     2024  50.549
# 1  38001 Adeje  Total     2023  50.167
# 2  38001 Adeje  Total     2022  49.270
# 3  38001 Adeje  Total     2021  48.733
# 4  38001 Adeje  Total     2020  49.030
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2894.csv' para table_code 2894
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  40001 Abades  Total     2024  859.0
# 1  40001 Abades  Total     2023  859.0
# 2  40001 Abades  Total     2022  839.0
# 3  40001 Abades  Total     2021  835.0
# 4  40001 Abades  Total     2020  857.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2895.csv' para table_code 2895
# Primeros registros de la tabla:
#         Municipios   Sexo  Periodo  Total
# 0  41001 Aguadulce  Total     2024  2.042
# 1  41001 Aguadulce  Total     2023  2.046
# 2  41001 Aguadulce  Total     2022  2.043
# 3  41001 Aguadulce  Total     2021  2.022
# 4  41001 Aguadulce  Total     2020  2.035
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2896.csv' para table_code 2896
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  42001 Abejar  Total     2024  386.0
# 1  42001 Abejar  Total     2023  376.0
# 2  42001 Abejar  Total     2022  273.0
# 3  42001 Abejar  Total     2021  273.0
# 4  42001 Abejar  Total     2020  286.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2900.csv' para table_code 2900
# Primeros registros de la tabla:
#           Municipios   Sexo  Periodo  Total
# 0  43001 Aiguamúrcia  Total     2024  957.0
# 1  43001 Aiguamúrcia  Total     2023  974.0
# 2  43001 Aiguamúrcia  Total     2022  961.0
# 3  43001 Aiguamúrcia  Total     2021  960.0
# 4  43001 Aiguamúrcia  Total     2020  930.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2899.csv' para table_code 2899
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  44001 Ababuj  Total     2024   74.0
# 1  44001 Ababuj  Total     2023   70.0
# 2  44001 Ababuj  Total     2022   72.0
# 3  44001 Ababuj  Total     2021   76.0
# 4  44001 Ababuj  Total     2020   77.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2902.csv' para table_code 2902
# Primeros registros de la tabla:
#       Municipios   Sexo  Periodo  Total
# 0  45001 Ajofrín  Total     2024  2.350
# 1  45001 Ajofrín  Total     2023  2.340
# 2  45001 Ajofrín  Total     2022  2.290
# 3  45001 Ajofrín  Total     2021  2.236
# 4  45001 Ajofrín  Total     2020  2.259
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2903.csv' para table_code 2903
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  46001 Ademuz  Total     2024  1.004
# 1  46001 Ademuz  Total     2023  1.004
# 2  46001 Ademuz  Total     2022  1.000
# 3  46001 Ademuz  Total     2021  1.027
# 4  46001 Ademuz  Total     2020  1.037
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2904.csv' para table_code 2904
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  47001 Adalia  Total     2024   50.0
# 1  47001 Adalia  Total     2023   51.0
# 2  47001 Adalia  Total     2022   54.0
# 3  47001 Adalia  Total     2021   52.0
# 4  47001 Adalia  Total     2020   53.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2906.csv' para table_code 2906
# Primeros registros de la tabla:
#        Municipios   Sexo  Periodo  Total
# 0  49002 Abezames  Total     2024   60.0
# 1  49002 Abezames  Total     2023   64.0
# 2  49002 Abezames  Total     2022   65.0
# 3  49002 Abezames  Total     2021   58.0
# 4  49002 Abezames  Total     2020   59.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2907.csv' para table_code 2907
# Primeros registros de la tabla:
#      Municipios   Sexo  Periodo  Total
# 0  50001 Abanto  Total     2024   80.0
# 1  50001 Abanto  Total     2023   86.0
# 2  50001 Abanto  Total     2022   89.0
# 3  50001 Abanto  Total     2021   89.0
# 4  50001 Abanto  Total     2020   92.0
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2908.csv' para table_code 2908
# Primeros registros de la tabla:
#   Municipios   Sexo  Periodo   Total
# 0   51 Ceuta  Total     2024  83.229
# 1   51 Ceuta  Total     2023  83.039
# 2   51 Ceuta  Total     2022  83.117
# 3   51 Ceuta  Total     2021  83.517
# 4   51 Ceuta  Total     2020  84.202
# --------------------------------------------------
# Archivo CSV guardado como 'tabla_2909.csv' para table_code 2909
# Primeros registros de la tabla:
#    Municipios   Sexo  Periodo   Total
# 0  52 Melilla  Total     2024  85.811
# 1  52 Melilla  Total     2023  85.491
# 2  52 Melilla  Total     2022  85.170
# 3  52 Melilla  Total     2021  86.261
# 4  52 Melilla  Total     2020  87.076
# --------------------------------------------------

# %% [markdown]
# ### Unimos tablas

# %%
import os
import glob
import pandas as pd

# Directorio donde se encuentran los archivos CSV
directorio = "/content/"
# Patrón para encontrar los archivos que empiezan con "tabla_"
patron = os.path.join(directorio, "tabla_*.csv")

# Obtenemos la lista de archivos que coinciden
archivos = glob.glob(patron)
print("Archivos encontrados:", archivos)

# Lista para almacenar cada DataFrame
lista_df = []

for archivo in archivos:
    # Extraer el table_code a partir del nombre del archivo
    # Se asume que el nombre es del tipo "tabla_<table_code>.csv"
    nombre_archivo = os.path.basename(archivo)  # Ej: "tabla_2855.csv"
    table_code = nombre_archivo.split('_')[1].split('.')[0]

    # Leer el archivo CSV; se asume que el separador es tabulador y codificación UTF-8
    df_temp = pd.read_csv(archivo, sep='\t', encoding='utf-8')

    # Agregar una columna con el código de tabla para referencia
    df_temp['table_code'] = table_code

    lista_df.append(df_temp)

# Unir todos los DataFrames verticalmente
df_unido = pd.concat(lista_df, ignore_index=True)

print("Vista previa del DataFrame unido:")
print(df_unido.head())
# Out:
# Archivos encontrados: ['/content/tabla_2901.csv', '/content/tabla_2893.csv', '/content/tabla_2902.csv', '/content/tabla_2891.csv', '/content/tabla_2905.csv', '/content/tabla_2878.csv', '/content/tabla_2880.csv', '/content/tabla_2899.csv', '/content/tabla_2894.csv', '/content/tabla_2886.csv', '/content/tabla_2871.csv', '/content/tabla_2885.csv', '/content/tabla_2875.csv', '/content/tabla_2906.csv', '/content/tabla_2879.csv', '/content/tabla_2862.csv', '/content/tabla_2859.csv', '/content/tabla_2866.csv', '/content/tabla_2876.csv', '/content/tabla_2864.csv', '/content/tabla_2889.csv', '/content/tabla_2868.csv', '/content/tabla_2904.csv', '/content/tabla_2882.csv', '/content/tabla_2896.csv', '/content/tabla_2890.csv', '/content/tabla_2861.csv', '/content/tabla_2907.csv', '/content/tabla_2865.csv', '/content/tabla_2888.csv', '/content/tabla_2870.csv', '/content/tabla_2895.csv', '/content/tabla_2858.csv', '/content/tabla_2854.csv', '/content/tabla_2872.csv', '/content/tabla_2863.csv', '/content/tabla_2908.csv', '/content/tabla_2869.csv', '/content/tabla_2857.csv', '/content/tabla_2884.csv', '/content/tabla_2900.csv', '/content/tabla_2881.csv', '/content/tabla_2855.csv', '/content/tabla_2873.csv', '/content/tabla_2909.csv', '/content/tabla_2892.csv', '/content/tabla_2874.csv', '/content/tabla_2856.csv', '/content/tabla_2860.csv', '/content/tabla_2903.csv', '/content/tabla_2877.csv', '/content/tabla_2883.csv']
# Vista previa del DataFrame unido:
#      Municipios   Sexo  Periodo  Total table_code
# 0  14001 Adamuz  Total     2024  4.091       2901
# 1  14001 Adamuz  Total     2023  4.092       2901
# 2  14001 Adamuz  Total     2022  4.125       2901
# 3  14001 Adamuz  Total     2021  4.141       2901
# 4  14001 Adamuz  Total     2020  4.137       2901

# %%
len(df_unido.Municipios.unique()) # 8188 test
# Out:
# 8188

# %% [markdown]
# ### Creamos la carpeta preprocesados si no existe

# %%
# Creamos la carpeta preprocesados si no existe
if not os.path.exists('preprocesados'):
    os.makedirs('preprocesados')

# Guardamos el DataFrame unido en un archivo CSV dentro de la carpeta preprocesados
df_unido.to_csv('preprocesados/df_unido.csv', index=False)
print("DataFrame unido guardado en preprocesados/df_unido.csv")
# Out:
# DataFrame unido guardado en preprocesados/df_unido.csv

# %% [markdown]
# ### seleccionamos solo total de la columna SEXO creamos mun_code y Municipios_name

# %%
import pandas as pd

# Leer la tabla descargada (asegúrate de que el separador y la codificación sean los correctos)
df = pd.read_csv("/content/preprocesados/df_unido.csv", sep=",", encoding="utf-8")

# Filtrar solo las filas donde la columna 'Sexo' es 'Total'
df = df[df['Sexo'] == 'Total']

# Determinar la columna que contiene el código y el nombre del municipio.
# Se asume que puede llamarse "Código" o "Municipio", y si no existe, se toma la primera columna.
col = None
for candidate in ["Código", "Municipio"]:
    if candidate in df.columns:
        col = candidate
        break
if col is None:
    col = df.columns[0]

# Mostrar las primeras filas para ver cómo está el contenido antes de dividir
print("Antes de dividir:")
print(df.head())

# Dividir la columna en dos nuevas columnas: "mun_code" y "Municipios_name".
# Se asume que el valor es de la forma "código nombre" y se divide en el primer espacio.
df[['mun_code', 'Municipios_name']] = df[col].astype(str).str.split(" ", n=1, expand=True)

# Opcional: reorganizar las columnas para mayor claridad
cols = list(df.columns)
# Por ejemplo, mover las nuevas columnas al inicio
cols_new = ['mun_code', 'Municipios_name'] + [c for c in cols if c not in ['mun_code', 'Municipios_name']]
df = df[cols_new]

print("\nDespués de dividir y filtrar:")
print(df.head())
# Out:
# Antes de dividir:
#      Municipios   Sexo  Periodo  Total  table_code
# 0  14001 Adamuz  Total     2024  4.091        2901
# 1  14001 Adamuz  Total     2023  4.092        2901
# 2  14001 Adamuz  Total     2022  4.125        2901
# 3  14001 Adamuz  Total     2021  4.141        2901
# 4  14001 Adamuz  Total     2020  4.137        2901
#
# Después de dividir y filtrar:
#   mun_code Municipios_name    Municipios   Sexo  Periodo  Total  table_code
# 0    14001          Adamuz  14001 Adamuz  Total     2024  4.091        2901
# 1    14001          Adamuz  14001 Adamuz  Total     2023  4.092        2901
# 2    14001          Adamuz  14001 Adamuz  Total     2022  4.125        2901
# 3    14001          Adamuz  14001 Adamuz  Total     2021  4.141        2901
# 4    14001          Adamuz  14001 Adamuz  Total     2020  4.137        2901

# %%
# Creamos la carpeta preprocesados si no existe
if not os.path.exists('preprocesados'):
    os.makedirs('preprocesados')

# Guardamos el DataFrame unido en un archivo CSV dentro de la carpeta preprocesados
df_unido.to_csv('preprocesados/df_unido2.csv', index=False)
print("DataFrame unido guardado en preprocesados/df_unido2.csv")
# Out:
# DataFrame unido guardado en preprocesados/df_unido2.csv

# %%
# prompt: mostramos el listado completo de Municipios diferentes pero que se muestre completo por pantalla como listado

# Assuming df is your DataFrame with the 'Municipios_name' column
municipios_list = df['Municipios_name'].unique().tolist()
print("valores unicos en Municipios_name" ,len(municipios_list) ) # 8131 test
print("numero total en Municipios_name",len(df_unido.Municipios.unique()) )# 8188 test
# Out:
# valores unicos en Municipios_name 8131
# numero total en Municipios_name 8188

# %%
# prompt: df mostramos porcentajes de nan

# Calcula el porcentaje de valores NaN en cada columna del DataFrame df
percentage_nan = df.isnull().mean() * 100

# Imprime los resultados
print("Porcentaje de valores NaN en cada columna:")
print(percentage_nan) # control Total 3.685798
# Out:
# Porcentaje de valores NaN en cada columna:
# mun_code           0.000000
# Municipios_name    0.000000
# Municipios         0.000000
# Sexo               0.000000
# Periodo            0.000000
# Total              3.685798
# table_code         0.000000
# dtype: float64

# %%
# identificamos las filas que tienen nan y las mostramos

import pandas as pd

# Assuming df is your DataFrame
rows_with_nan = df[df.isnull().any(axis=1)]
print("Rows with NaN values:")
rows_with_nan
# Out:
# Rows with NaN values:
#        mun_code            Municipios_name                       Municipios  \
# 27        14001                     Adamuz                     14001 Adamuz
# 114       14002     Aguilar de la Frontera     14002 Aguilar de la Frontera
# 201       14003                Alcaracejos                14003 Alcaracejos
# 288       14004                Almedinilla                14004 Almedinilla
# 375       14005          Almodóvar del Río          14005 Almodóvar del Río
# ...         ...                        ...                              ...
# 711948    30040                       Ulea                       30040 Ulea
# 712035    30041                  Unión, La                  30041 Unión, La
# 712122    30042  Villanueva del Río Segura  30042 Villanueva del Río Segura
# 712209    30043                      Yecla                      30043 Yecla
# 712296    30003                    Águilas                    30003 Águilas
#
#          Sexo  Periodo Total  table_code
# 27      Total     1997   NaN        2901
# 114     Total     1997   NaN        2901
# 201     Total     1997   NaN        2901
# 288     Total     1997   NaN        2901
# 375     Total     1997   NaN        2901
# ...       ...      ...   ...         ...
# 711948  Total     1997   NaN        2883
# 712035  Total     1997   NaN        2883
# 712122  Total     1997   NaN        2883
# 712209  Total     1997   NaN        2883
# 712296  Total     1997   NaN        2883
#
# [8752 rows x 7 columns]

# %%
# imprimimos valores unicos de la columna Periodo  de rows_with_nan

# Assuming df is your DataFrame with the 'Periodo' column
periodos_list = rows_with_nan['Periodo'].unique().tolist()
print("Valores únicos en la columna Periodo:", periodos_list)
# Out:
# Valores únicos en la columna Periodo: [1997, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1996, 2023, 2022, 2021, 2020, 2019, 2024]

# %%
# prompt: imprime un mensaje que diga en una sola linea tenemos en percentage_nan.Total porciento en la columna Total, vamos a eliminar estas filas con nan

print(f"En la columna Total, tenemos un {percentage_nan.Total:.2f}% de valores NaN. Vamos a eliminar estas filas con NaN.")
# control: En la columna Total, tenemos un 3.69% de valores NaN. Vamos a eliminar estas filas con NaN.
# Out:
# En la columna Total, tenemos un 3.69% de valores NaN. Vamos a eliminar estas filas con NaN.

# %% [markdown]
# ### eliminamos las filas (DESCARTAMOS ESTE PASO) ⚠️⚠️

# %%
# eliminamos las filas

# Assuming df is your DataFrame with NaN values
# df = df.dropna(subset=['Total'])

# Print the updated DataFrame (optional)
# print("DataFrame after removing rows with NaN in 'Total' column:")
# print(df.head())

# Creamos la carpeta preprocesados si no existe
# if not os.path.exists('preprocesados'):
#     os.makedirs('preprocesados')

# Guardamos el DataFrame unido en un archivo CSV dentro de la carpeta preprocesados
# df.to_csv('preprocesados/df_unido3.csv', index=False)
# print("DataFrame unido guardado en preprocesados/df_unido3.csv")

# %%
## (DESCARTAMOS ESTE PASO) ⚠️⚠️


# mostramos porcentajes de nan nuevamente
municipios_list = df['Municipios_name'].unique().tolist()
print("valores unicos en Municipios_name" ,len(municipios_list) ) # 8131 test
print("numero total en Municipios_name",len(df_unido.Municipios.unique()) )# 8188 test

# Calcula el porcentaje de valores NaN en cada columna del DataFrame df
percentage_nan = df.isnull().mean() * 100

# Imprime los resultados
print ("## (DESCARTAMOS ESTE PASO) ⚠️⚠️")
print("Porcentaje de valores NaN en cada columna: ")
percentage_nan
# Out:
# valores unicos en Municipios_name 8131
# numero total en Municipios_name 8188
# ## (DESCARTAMOS ESTE PASO) ⚠️⚠️
# Porcentaje de valores NaN en cada columna:
# mun_code           0.000000
# Municipios_name    0.000000
# Municipios         0.000000
# Sexo               0.000000
# Periodo            0.000000
# Total              3.685798
# table_code         0.000000
# dtype: float64

# %% [markdown]
# ### pivotamos

# %%
# ahora vamos a crear un que solo tenga mun_code y las cifras totales y las fechas como variables, es decir tendremos num_code y las fechas como variables, tantas variables como fechas dispongamos

# Cargar el DataFrame desde el archivo CSV
df = pd.read_csv('/content/preprocesados/df_unido3.csv')

# Crear un DataFrame con solo mun_code, Total y las fechas como columnas
df_pivot = df.pivot(index='mun_code', columns='Periodo', values='Total')

# Restablecer el índice para que mun_code sea una columna
df_pivot = df_pivot.reset_index()

print(df_pivot.head())

# Guardar el nuevo DataFrame en un archivo CSV
df_pivot.to_csv('preprocesados/df_pivot.csv', index=False)
print("DataFrame pivot guardado en preprocesados/df_pivot.csv")
# Out:
# Periodo  mun_code       1996       1998       1999       2000       2001  \
# 0               1    281.821    284.595    285.748    286.497    288.793
# 1               2     359.01    358.597    361.021    363.263    367.283
# 2               3  1.379.762  1.388.933  1.410.946  1.445.144  1.490.265
# 3               4    501.761    505.448    512.843    518.229    533.168
# 4               5    169.342    167.132    166.259    164.991    163.885
#
# Periodo       2002       2003       2004       2005  ...       2015  \
# 0           291.86     294.36    295.905    299.957  ...    323.648
# 1          371.787    376.556    379.448     384.64  ...     394.58
# 2        1.557.968  1.632.349  1.657.040  1.732.389  ...  1.855.047
# 3          546.498     565.31    580.077    612.315  ...    701.211
# 4          165.138     165.48    166.108    167.032  ...    164.925
#
# Periodo       2016       2017       2018       2019       2020       2021  \
# 0          324.126    326.574    328.868    331.549     333.94    333.626
# 1          392.118    390.032    388.786    388.167     388.27    386.464
# 2        1.836.459  1.825.332  1.838.819  1.858.683  1.879.888  1.881.762
# 3          704.297    706.672     709.34     716.82    727.945    731.792
# 4          162.514      160.7    158.498     157.64    157.664    158.421
#
# Periodo       2022       2023       2024
# 0          334.412    336.686    339.137
# 1          385.727    387.174    388.599
# 2        1.901.594  1.950.357  1.991.259
# 3          740.534     753.92     763.03
# 4           158.14    158.407    158.989
#
# [5 rows x 29 columns]
# DataFrame pivot guardado en preprocesados/df_pivot.csv

# %%
df_pivot.head()
# Out:
# Periodo  mun_code       1996       1998       1999       2000       2001  \
# 0               1    281.821    284.595    285.748    286.497    288.793
# 1               2     359.01    358.597    361.021    363.263    367.283
# 2               3  1.379.762  1.388.933  1.410.946  1.445.144  1.490.265
# 3               4    501.761    505.448    512.843    518.229    533.168
# 4               5    169.342    167.132    166.259    164.991    163.885
#
# Periodo       2002       2003       2004       2005  ...       2015  \
# 0           291.86     294.36    295.905    299.957  ...    323.648
# 1          371.787    376.556    379.448     384.64  ...     394.58
# 2        1.557.968  1.632.349  1.657.040  1.732.389  ...  1.855.047
# 3          546.498     565.31    580.077    612.315  ...    701.211
# 4          165.138     165.48    166.108    167.032  ...    164.925
#
# Periodo       2016       2017       2018       2019       2020       2021  \
# 0          324.126    326.574    328.868    331.549     333.94    333.626
# 1          392.118    390.032    388.786    388.167     388.27    386.464
# 2        1.836.459  1.825.332  1.838.819  1.858.683  1.879.888  1.881.762
# 3          704.297    706.672     709.34     716.82    727.945    731.792
# 4          162.514      160.7    158.498     157.64    157.664    158.421
#
# Periodo       2022       2023       2024
# 0          334.412    336.686    339.137
# 1          385.727    387.174    388.599
# 2        1.901.594  1.950.357  1.991.259
# 3          740.534     753.92     763.03
# 4           158.14    158.407    158.989
#
# [5 rows x 29 columns]

# %%
import pandas as pd

# Cargar el DataFrame desde el archivo CSV
df_pivot = pd.read_csv('/content/preprocesados/df_pivot.csv')

# Calcular el porcentaje de valores NaN por fecha
nan_percentage_by_date = df_pivot.isnull().mean() * 100

# Mostrar el porcentaje de NaN por fecha
print("Porcentaje de valores NaN por fecha:")
print(nan_percentage_by_date)

# Calcular el recuento total de valores NaN en el DataFrame
total_nan_count = df_pivot.isnull().sum().sum()

# Calcular el porcentaje de valores NaN en relación al total de valores en el DataFrame
total_values = df_pivot.size
total_nan_percentage = (total_nan_count / total_values) * 100

# Mostrar el recuento total de valores NaN y su porcentaje
print("\nRecuento total de valores NaN:", total_nan_count)
print("Porcentaje total de valores NaN:", total_nan_percentage)
# Out:
# Porcentaje de valores NaN por fecha:
# mun_code    0.000000
# 1996        0.488520
# 1998        0.464094
# 1999        0.427455
# 2000        0.390816
# 2001        0.354177
# 2002        0.341964
# 2003        0.341964
# 2004        0.329751
# 2005        0.329751
# 2006        0.317538
# 2007        0.305325
# 2008        0.293112
# 2009        0.293112
# 2010        0.268686
# 2011        0.244260
# 2012        0.244260
# 2013        0.232047
# 2014        0.232047
# 2015        0.207621
# 2016        0.134343
# 2017        0.146556
# 2018        0.146556
# 2019        0.061065
# 2020        0.061065
# 2021        0.061065
# 2022        0.061065
# 2023        0.061065
# 2024        0.048852
# dtype: float64
#
# Recuento total de valores NaN: 564
# Porcentaje total de valores NaN: 0.2375216885939053

# %%
df_pivot.columns
# Out:
# Index(['mun_code', '1996', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024'],
#       dtype='object')

# %%
# Cargar el DataFrame desde el archivo CSV
df_pivot = pd.read_csv('/content/preprocesados/df_pivot.csv')

# Creamos una copia para trabajar
df_pivot_numerico = df_pivot.copy()

# Reemplazar puntos por nada y comas por punto en todas las columnas
df_pivot_numerico = df_pivot_numerico.applymap(lambda x: str(x).replace('.', '').replace(',', '.') if isinstance(x, str) else x)

# Convertir todas las columnas a numérico (float), forzando coerción de errores
df_pivot_numerico = df_pivot_numerico.apply(pd.to_numeric, errors='coerce')

# Comprobamos el tipo de datos resultantes
tipos_datos = df_pivot_numerico.dtypes
print(tipos_datos)


# Convertimos solo las columnas numéricas (excepto 'mun_code') con reemplazo adecuado
for col in df_pivot.columns[1:]:  # omitimos 'mun_code'
    df_pivot[col] = df_pivot[col].astype(str).str.replace('.', '', regex=False).str.replace(',', '.', regex=False)

# Convertimos todo a numérico (excepto 'mun_code')
df_pivot_numerico = df_pivot.copy()
for col in df_pivot_numerico.columns[1:]:
    df_pivot_numerico[col] = pd.to_numeric(df_pivot_numerico[col], errors='coerce')

# Revisamos los tipos de datos
print(df_pivot_numerico.dtypes)
# Out:
# <ipython-input-241-d538d436b9f8>:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_pivot_numerico = df_pivot_numerico.applymap(lambda x: str(x).replace('.', '').replace(',', '.') if isinstance(x, str) else x)
# mun_code      int64
# 1996        float64
# 1998        float64
# 1999        float64
# 2000        float64
# 2001        float64
# 2002        float64
# 2003        float64
# 2004        float64
# 2005        float64
# 2006        float64
# 2007        float64
# 2008        float64
# 2009        float64
# 2010        float64
# 2011        float64
# 2012        float64
# 2013        float64
# 2014        float64
# 2015        float64
# 2016        float64
# 2017        float64
# 2018        float64
# 2019        float64
# 2020        float64
# 2021        float64
# 2022        float64
# 2023        float64
# 2024        float64
# dtype: object

# %%
# guardamos df_pivot_numerico

# Guardar df_pivot_numerico en un archivo (opcional)
df_pivot_numerico.to_csv('preprocesados/df_pivot_numerico.csv', index=False)
print("DataFrame df_pivot_numerico guardado en preprocesados/df_pivot_numerico.csv")
# Out:
# DataFrame df_pivot_numerico guardado en preprocesados/df_pivot_numerico.csv

# %% [markdown]
# ### mostramos OUTLIERS

# %%
# Cargar el DataFrame desde el archivo CSV
df_pivot_numerico = pd.read_csv('/content/preprocesados/df_pivot_numerico.csv')

# Calcular el número de filas en el DataFrame
num_rows = df_pivot_numerico.shape[0]

# Mostrar el número de filas
print("Número de filas en el DataFrame df_pivot_numerico:", num_rows)
# Out:
# Número de filas en el DataFrame df_pivot_numerico: 8188

# %% [markdown]
# #### graficamos test 50903

# %%
import matplotlib.pyplot as plt

# Filtrar por el municipio con código 50903
municipio_50903 = df_pivot_numerico[df_pivot_numerico['mun_code'] == 50903]

# Transponer para graficar correctamente
serie_50903 = municipio_50903.drop(columns='mun_code').T
serie_50903.columns = ['Población']
serie_50903.reset_index(inplace=True)
serie_50903.columns = ['Año', 'Población']
serie_50903['Año'] = serie_50903['Año'].astype(str)

# Mostrar los valores
print(serie_50903)

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(serie_50903['Año'], serie_50903['Población'], marker='o')
plt.title("Evolución de la población - Municipio 50903")
plt.xlabel("Año")
plt.ylabel("Población")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#      Año  Población
# 0   1996        NaN
# 1   1998        NaN
# 2   1999        NaN
# 3   2000        NaN
# 4   2001        NaN
# 5   2002        NaN
# 6   2003        NaN
# 7   2004        NaN
# 8   2005        NaN
# 9   2006        NaN
# 10  2007     2849.0
# 11  2008     2878.0
# 12  2009     2868.0
# 13  2010     2888.0
# 14  2011     2885.0
# 15  2012     2838.0
# 16  2013     2837.0
# 17  2014      282.0
# 18  2015     2793.0
# 19  2016     2753.0
# 20  2017     2721.0
# 21  2018     2696.0
# 22  2019      272.0
# 23  2020     2745.0
# 24  2021     2768.0
# 25  2022     2827.0
# 26  2023     2866.0
# 27  2024     2854.0

# %% [markdown]
# #### codigo para la detección de outliers test 50903

# %%
# Usamos el método IQR (rango intercuartílico) para detectar outliers
Q1 = serie_50903['Población'].quantile(0.25)
Q3 = serie_50903['Población'].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Identificar outliers
serie_50903['Es_outlier'] = (
    (serie_50903['Población'] < limite_inferior) |
    (serie_50903['Población'] > limite_superior)
)

# Mostrar los valores que son outliers
outliers_detectados = serie_50903[serie_50903['Es_outlier'] == True]
outliers_detectados
# Out:
#      Año  Población  Es_outlier
# 17  2014      282.0        True
# 22  2019      272.0        True

# %%
# Creamos una copia del DataFrame para análisis de outliers
df_outliers = df_pivot_numerico.copy()

# Aplicamos detección de outliers fila por fila (por municipio) usando IQR
def detectar_outliers_fila(fila):
    valores = fila[1:]  # excluir 'mun_code'
    Q1 = valores.quantile(0.25)
    Q3 = valores.quantile(0.75)
    IQR = Q3 - Q1
    limite_inf = Q1 - 1.5 * IQR
    limite_sup = Q3 + 1.5 * IQR
    return ((valores < limite_inf) | (valores > limite_sup)).sum()


# Aplicamos a cada fila y contamos cuántos outliers tiene cada municipio
df_outliers['num_outliers'] = df_outliers.apply(detectar_outliers_fila, axis=1)

# Filtrar municipios que tengan al menos un outlier
municipios_con_outliers = df_outliers[df_outliers['num_outliers'] > 0][['mun_code', 'num_outliers']]
municipios_con_outliers
# Out:
#       mun_code  num_outliers
# 0            1             3
# 1            2             5
# 4            5             5
# 5            6             2
# 8            9             7
# ...        ...           ...
# 8181     50297             3
# 8182     50298             2
# 8185     50903             2
# 8186     51001             1
# 8187     52001             4
#
# [2558 rows x 2 columns]

# %%
total_outliers = municipios_con_outliers['num_outliers'].sum()

print(f"La suma total de 'num_outliers' en municipios_con_outliers es: {total_outliers}")
# v1 = La suma total de 'num_outliers' en municipios_con_outliers es: 7409
# v2 = La suma total de 'num_outliers' en municipios_con_outliers es: 7409
# Out:
# La suma total de 'num_outliers' en municipios_con_outliers es: 7409

# %% [markdown]
# ### Corregimos outliers. primera parte

# %%
# Función  para corregir outliers sin usar otros outliers como vecinos
def corregir_outliers_vecinos_excluyendo_outliers(fila, n_max=5):
    codigo = fila['mun_code']
    valores = fila[1:].copy()  # excluir 'mun_code'
    index = valores.index

    # Detectar outliers en la fila
    Q1 = valores.quantile(0.25)
    Q3 = valores.quantile(0.75)
    IQR = Q3 - Q1
    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR
    outlier_mask = (valores < lim_inf) | (valores > lim_sup)
    outliers_idx = valores[outlier_mask].index

    # Reemplazar cada outlier con media de vecinos válidos que NO sean outliers
    for idx in outliers_idx:
        pos = index.get_loc(idx)
        reemplazado = False

        for n in range(1, n_max + 1):
            izquierda = valores.iloc[max(0, pos - n):pos]
            derecha = valores.iloc[pos + 1:pos + 1 + n]

            # Excluir vecinos que también son outliers
            izquierda = izquierda[~outlier_mask.iloc[max(0, pos - n):pos]]
            derecha = derecha[~outlier_mask.iloc[pos + 1:pos + 1 + n]]

            vecinos_validos = pd.concat([izquierda, derecha]).dropna()

            if len(vecinos_validos) >= 2:  # mínimo un valor a cada lado
                valores.iloc[pos] = vecinos_validos.mean()
                reemplazado = True
                break

        # Si no se reemplaza, se mantiene el valor original

    return pd.concat([pd.Series({'mun_code': codigo}), valores])

# Aplicar la nueva versión de la corrección
df_outliers_puros_corregidos = df_pivot_numerico.apply(lambda fila: corregir_outliers_vecinos_excluyendo_outliers(fila, n_max=5), axis=1)

# Volver a contar outliers tras esta corrección más estricta
df_outliers_puros_corregidos['num_outliers'] = df_outliers_puros_corregidos.apply(contar_outliers, axis=1)
outliers_filtrados = df_outliers_puros_corregidos[df_outliers_puros_corregidos['num_outliers'] > 0][['mun_code', 'num_outliers']]
total_outliers_puros = outliers_filtrados['num_outliers'].sum()

total_outliers_puros

# v1 = np.int64(700)
# v2 = np.int64(700)
# Out:
# np.int64(700)

# %%
df_outliers_puros_corregidos.to_csv('preprocesados/df_outliers_puros_corregidos.csv', index=False)
print("DataFrame df_outliers_puros_corregidos guardado en preprocesados/df_outliers_puros_corregidos.csv")
# Out:
# DataFrame df_outliers_puros_corregidos guardado en preprocesados/df_outliers_puros_corregidos.csv

# %% [markdown]
# #### graficamos test 50903

# %%
import matplotlib.pyplot as plt

# Filtrar por el municipio con código 50903
municipio_50903 = df_outliers_puros_corregidos[df_outliers_puros_corregidos['mun_code'] == 6126.0]

# Transponer para graficar correctamente
serie_50903 = municipio_50903.drop(columns='mun_code').T
serie_50903.columns = ['Población']
serie_50903.reset_index(inplace=True)
serie_50903.columns = ['Año', 'Población']
serie_50903['Año'] = serie_50903['Año'].astype(str)

# Mostrar los valores
print(serie_50903)

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(serie_50903['Año'], serie_50903['Población'], marker='o')
plt.title("Evolución de la población - Municipio 50903")
plt.xlabel("Año")
plt.ylabel("Población")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#              Año    Población
# 0           1996  2877.000000
# 1           1998  2813.000000
# 2           1999  2839.000000
# 3           2000  2768.000000
# 4           2001  2793.000000
# 5           2002  2739.333333
# 6           2003  2687.000000
# 7           2004  2657.000000
# 8           2005  2611.000000
# 9           2006  2714.000000
# 10          2007  2819.000000
# 11          2008  2814.000000
# 12          2009  2826.000000
# 13          2010  2795.000000
# 14          2011  2797.000000
# 15          2012  2777.500000
# 16          2013  2758.000000
# 17          2014  2717.000000
# 18          2015  2692.000000
# 19          2016  2685.500000
# 20          2017  2679.000000
# 21          2018  2645.000000
# 22          2019  2623.000000
# 23          2020  2601.000000
# 24          2021  2575.000000
# 25          2022  2553.000000
# 26          2023  2538.000000
# 27          2024  2542.000000
# 28  num_outliers     0.000000

# %%
# prompt: filtra de df_correccion_vecinos por num code 1.0

# Assuming df_correccion_vecinos is your DataFrame
df_filtrado = df_outliers_puros_corregidos[df_outliers_puros_corregidos['mun_code'] == 1.0]

# Print the filtered DataFrame (optional)
df_filtrado
# Out:
#    mun_code      1996      1998      1999      2000      2001           2002  \
# 0       1.0  281821.0  284595.0  285748.0  286497.0  288793.0  290398.333333
#
#        2003      2004      2005  ...      2016      2017      2018      2019  \
# 0  294885.0  295905.0  299957.0  ...  324126.0  326574.0  328868.0  331549.0
#
#        2020      2021      2022      2023      2024  num_outliers
# 0  332587.5  333626.0  334412.0  336686.0  339137.0             0
#
# [1 rows x 30 columns]

# %%
import matplotlib.pyplot as plt

# Filtrar por el municipio con código 50903
municipio_50903 = df_outliers_puros_corregidos[df_outliers_puros_corregidos['mun_code'] == 5267]

# Transponer para graficar correctamente
serie_50903 = municipio_50903.drop(columns='mun_code').T
serie_50903.columns = ['Población']
serie_50903.reset_index(inplace=True)
serie_50903.columns = ['Año', 'Población']
serie_50903['Año'] = serie_50903['Año'].astype(str)

# Mostrar los valores
print(serie_50903)

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(serie_50903['Año'], serie_50903['Población'], marker='o')
plt.title("Evolución de la población - Municipio 50903")
plt.xlabel("Año")
plt.ylabel("Población")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#              Año  Población
# 0           1996     1420.0
# 1           1998     1460.0
# 2           1999     1400.0
# 3           2000     1390.0
# 4           2001     1350.0
# 5           2002     1300.0
# 6           2003     1270.0
# 7           2004     1250.0
# 8           2005     1250.0
# 9           2006     1290.0
# 10          2007     1430.0
# 11          2008     1360.0
# 12          2009     1310.0
# 13          2010     1290.0
# 14          2011     1240.0
# 15          2012     1190.0
# 16          2013     1170.0
# 17          2014     1140.0
# 18          2015     1110.0
# 19          2016     1140.0
# 20          2017     1130.0
# 21          2018     1150.0
# 22          2019     1160.0
# 23          2020     1070.0
# 24          2021     1000.0
# 25          2022      920.0
# 26          2023      920.0
# 27          2024      920.0
# 28  num_outliers        0.0

# %%
# Calcular el porcentaje de valores NaN por fecha
nan_percentage_by_date = df_outliers_puros_corregidos.isnull().mean() * 100

# Mostrar el porcentaje de NaN por fecha
print("Porcentaje de valores NaN por fecha:")
print(nan_percentage_by_date)
# Out:
# Porcentaje de valores NaN por fecha:
# mun_code        0.000000
# 1996            0.488520
# 1998            0.464094
# 1999            0.427455
# 2000            0.390816
# 2001            0.354177
# 2002            0.341964
# 2003            0.341964
# 2004            0.329751
# 2005            0.329751
# 2006            0.317538
# 2007            0.305325
# 2008            0.293112
# 2009            0.293112
# 2010            0.268686
# 2011            0.244260
# 2012            0.244260
# 2013            0.232047
# 2014            0.232047
# 2015            0.207621
# 2016            0.134343
# 2017            0.146556
# 2018            0.146556
# 2019            0.061065
# 2020            0.061065
# 2021            0.061065
# 2022            0.061065
# 2023            0.061065
# 2024            0.048852
# num_outliers    0.000000
# dtype: float64

# %%
total_nan_count = df_outliers_puros_corregidos.isnull().sum().sum()

# Calcular el porcentaje de valores NaN en relación al total de valores en el DataFrame
total_values = df_outliers_puros_corregidos.size
total_nan_percentage = (total_nan_count / total_values) * 100

# Mostrar el recuento total de valores NaN y su porcentaje
print("\nRecuento total de valores NaN en df_outliers_puros_corregidos:", total_nan_count)
print("Porcentaje total de valores NaN en df_outliers_puros_corregidos:", total_nan_percentage)
# Out:
# Recuento total de valores NaN en df_outliers_puros_corregidos: 564
# Porcentaje total de valores NaN en df_outliers_puros_corregidos: 0.22960429897410845

# %% [markdown]
# ### municipios con mas de 6 NAN

# %%
# Calcular el número de valores NaN en cada fila
nan_counts_per_row = df_outliers_puros_corregidos.isnull().sum(axis=1)

# Filtrar las filas que tienen más de 6 valores NaN
rows_with_more_than_6_nans = df_outliers_puros_corregidos[nan_counts_per_row > 6]

# Mostrar las filas que tienen más de 6 valores NaN
print("Filas con más de 6 valores NaN:")
rows_with_more_than_6_nans
# Out:
# Filas con más de 6 valores NaN:
#       mun_code    1996    1998    1999    2000    2001    2002    2003  \
# 433     4904.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 846     6903.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1815   10902.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1816   10903.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1817   10904.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1818   10905.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1863   11903.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2176   14901.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2177   14902.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2203   15026.0  2794.0  2733.0  2703.0  2646.0  2595.0  2555.0  2509.0
# 2240   15063.0  3263.0  3240.0  3221.0  3208.0  3219.0  3160.0  3157.0
# 2272   15902.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2786   18065.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2796   18077.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2819   18106.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2903   18914.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2904   18915.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2905   18916.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3361   21902.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4623   29902.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4624   29903.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4625   29904.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5348   36011.0  2771.0  2684.0  2592.0  2566.0  2523.0  2434.0  2313.0
# 5349   36012.0  4987.5  5012.0  4963.0  4786.0  4707.5  4629.0  4636.5
# 5400   36902.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5816   38901.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6233   41904.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6600   43907.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7306   46904.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7643   48915.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7644   48916.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8185   50903.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         2004    2005  ...    2016    2017    2018    2019    2020    2021  \
# 433      NaN     NaN  ...  2936.0  2939.0  2933.0  3009.0  3105.0  2959.0
# 846      NaN     NaN  ...  2544.0  2531.0  2518.0  2485.0  2492.0  2465.0
# 1815     NaN     NaN  ...  8580.0  8490.0  8680.0  8640.0  8680.0  8450.0
# 1816     NaN     NaN  ...  9400.0  9320.0  9340.0  9320.0  9320.0  9330.0
# 1817     NaN     NaN  ...  9310.0  9220.0  9210.0  9020.0  8790.0  8780.0
# 1818     NaN     NaN  ...  8300.0  8290.0  8140.0  7910.0  7820.0  7670.0
# 1863     NaN     NaN  ...     NaN     NaN     NaN  2753.0  2801.0  2821.0
# 2176     NaN     NaN  ...     NaN     NaN     NaN  1131.0  1148.0  1133.0
# 2177     NaN     NaN  ...     NaN     NaN     NaN  1399.0  1379.0  1365.0
# 2203  2463.0  2427.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2240  3154.0  3163.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2272     NaN     NaN  ...  5181.0  5133.0  5155.0  5101.0  5096.0  5170.0
# 2786     NaN     NaN  ...  7270.0  7280.0  7230.0  7050.0  6880.0  6850.0
# 2796     NaN     NaN  ...     NaN     NaN     NaN  5550.0  5560.0  5340.0
# 2819     NaN     NaN  ...  6460.0  6330.0  5990.0  6140.0  6230.0  6090.0
# 2903     NaN     NaN  ...  2094.0  2083.0  2086.0  2086.0  2066.0  2059.0
# 2904     NaN     NaN  ...  9070.0  8990.0  8900.0  8900.0  8780.0  8620.0
# 2905     NaN     NaN  ...     NaN     NaN     NaN  2682.0  2796.0  2892.0
# 3361     NaN     NaN  ...     NaN     NaN     NaN  1267.0  1253.0  1252.0
# 4623     NaN     NaN  ...  3304.0  3290.0  3288.0  3296.0  3288.0  3277.0
# 4624     NaN     NaN  ...   589.0   589.0   585.0   593.0   586.0   584.0
# 4625     NaN     NaN  ...   503.0   494.0   477.0   477.0   482.0   473.0
# 5348  2308.0  2333.0  ...  1781.0     NaN     NaN     NaN     NaN     NaN
# 5349  4644.0  4658.0  ...  4329.5     NaN     NaN     NaN     NaN     NaN
# 5400     NaN     NaN  ...     NaN  5698.0  5698.0  5699.0  5697.0  5719.0
# 5816     NaN     NaN  ...  1743.0  1776.0  1825.0  1870.0  1894.0  1936.0
# 6233     NaN     NaN  ...     NaN     NaN     NaN  2340.0  2343.0  2340.0
# 6600     NaN     NaN  ...  5846.0  5804.0  5842.0  5893.0  5956.0  5933.0
# 7306   927.0   927.0  ...   972.0   970.0   974.0  1012.0  1048.0  1030.0
# 7643     NaN     NaN  ...   432.0   420.0   427.0   413.0   404.0   411.0
# 7644     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 8185     NaN     NaN  ...  2753.0  2721.0  2696.0  2720.5  2745.0  2768.0
#
#         2022    2023    2024  num_outliers
# 433   2886.0  2931.0  3016.0             0
# 846   2414.0  2416.0  2437.0             0
# 1815  8490.0  8480.0  8440.0             0
# 1816  9240.0  9130.0  9090.0             0
# 1817  8690.0  8440.0  8540.0             0
# 1818  7670.0  7820.0  7750.0             0
# 1863  2797.0  2742.0  2739.0             0
# 2176  1109.0  1089.0  1067.0             0
# 2177  1341.0  1336.0  1333.0             0
# 2203     NaN     NaN     NaN             0
# 2240     NaN     NaN     NaN             0
# 2272  5247.0  5203.0  5151.0             0
# 2786  6660.0  6500.0  6400.0             0
# 2796  5190.0  5430.0  5310.0             0
# 2819  5790.0  5820.0  6120.0             0
# 2903  2045.0  2061.0  2077.0             0
# 2904  8490.0  8360.0  8240.0             0
# 2905  3038.0  3115.0  3098.0             0
# 3361  1233.5  1215.0  1189.0             0
# 4623  3295.0  3302.0  3286.0             0
# 4624   582.0   588.0   589.0             0
# 4625   458.0   447.0   453.0             0
# 5348     NaN     NaN     NaN             1
# 5349     NaN     NaN     NaN             0
# 5400  5697.0  5687.0  5705.0             2
# 5816  1971.0  2016.0  2010.0             0
# 6233  2343.0  2325.0  2334.0             1
# 6600  5873.0  5922.0  5943.0             0
# 7306  1030.0  1030.0  1030.0             0
# 7643   405.0   398.0   409.0             0
# 7644     NaN     NaN  4572.0             0
# 8185  2827.0  2866.0  2854.0             0
#
# [32 rows x 30 columns]

# %%
# Creamos una copia del DataFrame df_outliers_puros_corregidos
df_nuevo = df_outliers_puros_corregidos.copy()

# Eliminamos las filas con más de 6 valores NaN
df_nuevo = df_nuevo.dropna(thresh=df_outliers_puros_corregidos.shape[1] - 6)

# Calcular el número de valores NaN en cada fila
nan_counts_per_row = df_nuevo.isnull().sum(axis=1)

# Filtrar las filas que tienen más de 6 valores NaN
rows_with_more_than_6_nans = df_nuevo[nan_counts_per_row > 6]

# Mostrar las filas que tienen más de 6 valores NaN
print("Filas con más de 6 valores NaN:")
rows_with_more_than_6_nans
# Out:
# DataFrame después de eliminar las filas con más de 6 NaN:
#    mun_code       1996       1998       1999       2000       2001  \
# 0       1.0   281821.0   284595.0   285748.0   286497.0   288793.0
# 1       2.0   359809.0   358597.0   361021.0   363263.0   367283.0
# 2       3.0  1379762.0  1388933.0  1410946.0  1445144.0  1490265.0
# 3       4.0   501761.0   505448.0   512843.0   518229.0   533168.0
# 4       5.0   169342.0   167132.0   166259.0   164991.0   163885.0
#
#            2002       2003       2004       2005  ...       2016       2017  \
# 0  2.903983e+05   294885.0   295905.0   299957.0  ...   324126.0   326574.0
# 1  3.717870e+05   376556.0   379448.0   383553.0  ...   392118.0   390032.0
# 2  1.557968e+06  1632349.0  1657040.0  1732389.0  ...  1836459.0  1825332.0
# 3  5.464980e+05    56531.0   580077.0   612315.0  ...   704297.0   706672.0
# 4  1.651380e+05   165623.0   166108.0   167032.0  ...   162514.0   160506.0
#
#         2018       2019       2020       2021       2022       2023  \
# 0   328868.0   331549.0   332587.5   333626.0   334412.0   336686.0
# 1   388786.0   388167.0   387315.5   386464.0   385727.0   387174.0
# 2  1838819.0  1858683.0  1879888.0  1881762.0  1901594.0  1950357.0
# 3    70934.0    71682.0   727945.0   731792.0   740534.0    75392.0
# 4   158498.0   158081.0   157664.0   158421.0   158414.0   158407.0
#
#         2024  num_outliers
# 0   339137.0             0
# 1   388599.0             0
# 2  1991259.0             0
# 3    76303.0             0
# 4   158989.0             0
#
# [5 rows x 30 columns]
# Filas con más de 6 valores NaN:
# Empty DataFrame
# Columns: [mun_code, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, num_outliers]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Guardamos las filas con más de 6 NaN como identificación de municipios borrados
rows_with_more_than_6_nans.to_csv('preprocesados/municipios_borrados.csv', index=False)
print("Municipios borrados guardados en preprocesados/municipios_borrados.csv")
# Out:
# Municipios borrados guardados en preprocesados/municipios_borrados.csv

# %%
# Calcular el recuento total de valores NaN en el DataFrame df_nuevo
total_nan_count_df_nuevo = df_nuevo.isnull().sum().sum()

# Mostrar el recuento total de valores NaN en df_nuevo
print("\nRecuento total de valores NaN en df_nuevo:", total_nan_count_df_nuevo)
len(df_nuevo)
# Out:
# Recuento total de valores NaN en df_nuevo: 34

# %% [markdown]
# ### interpolación 2 - final

# %%
# Copiamos para preservar el DataFrame original corregido
df_sin_nan = df_nuevo.copy()

# Interpolamos temporalmente (por filas, a través de años)
columnas_a_interpolar = [col for col in df_sin_nan.columns if col not in ['mun_code', 'num_outliers']]
df_sin_nan[columnas_a_interpolar] = df_sin_nan[columnas_a_interpolar].interpolate(axis=1, limit_direction='both')

# Aplicamos forward-fill y backward-fill para extremos que no se puedan interpolar (actualizado)
df_sin_nan[columnas_a_interpolar] = df_sin_nan[columnas_a_interpolar].ffill(axis=1).bfill(axis=1)

# Verificamos si aún quedan NaN después del proceso
nan_restantes_final = df_sin_nan.isna().sum().sum()

print(nan_restantes_final)
# Out:
# 0

# %%
# Guardamos df_sin_nan como cifras_poblacion_municipio.csv
df_sin_nan.to_csv('preprocesados/cifras_poblacion_municipio.csv', index=False)
print("DataFrame df_sin_nan guardado en preprocesados/cifras_poblacion_municipio.csv")
# Out:
# DataFrame df_sin_nan guardado en preprocesados/cifras_poblacion_municipio.csv

# %% [markdown]
# ## pre - informe

# %%
# Cargamos de nuevo para asegurarnos
df_unido = pd.read_csv('/content/preprocesados/df_unido3.csv')
df_borrados = pd.read_csv('/content/preprocesados/municipios_borrados.csv')

# Convertimos ambos a float para asegurarnos que estén en el mismo tipo numérico
df_unido['mun_code'] = pd.to_numeric(df_unido['mun_code'], errors='coerce')
df_borrados['mun_code'] = pd.to_numeric(df_borrados['mun_code'], errors='coerce')

# Filtramos los municipios borrados presentes en df_unido
municipios_borrados_final = df_unido[df_unido['mun_code'].isin(df_borrados['mun_code'])][['mun_code', 'Municipios_name']].drop_duplicates()
municipios_borrados_final
# Out:
#         mun_code              Municipios_name
# 784        14901            Fuente Carreteros
# 958        14902               Guijarrosa, La
# 23840      48916                     Usansolo
# 24065      48915              Ziortza-Bolibar
# 48774      18065               Dehesas Viejas
# 48868      18915     Domingo Pérez de Granada
# 49073      18077                       Fornes
# 49835      18106                        Játar
# 51356      18916             Torrenueva Costa
# 51474      18914                  Valderrubio
# 84244       6903                     Guadiana
# 93761      11903     San Martín del Tesorillo
# 95783      15026                      Cesuras
# 96836      15063                 Oza dos Ríos
# 96853      15902                  Oza-Cesuras
# 105992     29903                   Montecorto
# 106421     29904                      Serrato
# 106682     29902  Villanueva de la Concepción
# 112352     36011                      Cerdedo
# 112372     36902             Cerdedo-Cotobade
# 112380     36012                     Cotobade
# 130343     50903        Villamayor de Gállego
# 148141     41904          Palmar de Troya, El
# 165812     10903               Alagón del Río
# 169915     10905    Pueblonuevo de Miramontes
# 170764     10904                       Tiétar
# 171447     10902                    Vegaviana
# 179162      4904                    Balanegra
# 190287     43907                  Canonja, La
# 205081     38901       Pinar de El Hierro, El
# 208094     21902          Zarza-Perrunal, La
# 215576     46904           Benicull de Xúquer

# %%
print("Número de municipios total en df_unido es:", len(df_unido['mun_code'].unique()))
# Out:
# Número de municipios total en df_unido es: 8188

# %%
print("Número de municipios_borrados_final es:", len(municipios_borrados_final['mun_code'].unique()))
# Out:
# Número de municipios_borrados_final es: 32

# %%
municipios_borrados_final.to_csv('preprocesados/municipios_borrados_final.csv', index=False)
print("Municipios borrados finales guardados en preprocesados/municipios_borrados_final.csv")
# Out:
# Municipios borrados finales guardados en preprocesados/municipios_borrados_final.csv

# %% [markdown]
# ## 📜 Informe de Procesamiento y Limpieza de Datos
#
# ### 📌 Introducción
# Este informe documenta el proceso de recolección, limpieza y transformación de datos de población por municipio en España utilizando datos del INE (Instituto Nacional de Estadística). El objetivo ha sido generar un dataset robusto, completo y libre de valores atípicos o ausentes para su uso en análisis demográficos o de simulación.
#
# ---
#
# ### 🔧 Proceso Realizado
#
# | Etapa                  | DataFrame Generado                      | Descripción                                                             | Nº Filas | Nº Columnas | Nº NaN   |
# |------------------------|------------------------------------------|-------------------------------------------------------------------------|----------|-------------|----------|
# | Original               | `df_unido.csv`                          | Unión de tablas originales descargadas del INE                         | 425,833  | 9           | 3.69%    |
# | Limpieza Inicial       | `df_unido2.csv`                         | Selección de `Sexo=Total`, creación de `mun_code` y `Municipios_name` | 141,944  | 11          | 3.69%    |
# | Pivotado               | `df_pivot.csv`                          | Reestructuración: municipios como filas y años como columnas           | 8,131    | 29          | 564      |
# | Conversión Numérica    | `df_pivot_numerico.csv`                 | Conversión de texto a valores numéricos                                | 8,131    | 29          | 564      |
# | Corrección Outliers    | `df_outliers_puros_corregidos.csv`      | Reemplazo adaptativo de outliers con media de vecinos válidos          | 8,131    | 30          | 700      |
# | Eliminación Municipios | `df_nuevo.csv`                          | Eliminación de municipios con más de 6 NaN                             | 8,115    | 30          | 476      |
# | Imputación Final       | `cifras_poblacion_municipio.csv`        | Interpolación y forward/backward fill                                  | 8,115    | 30          | **0**    |
#
# ---
#
# ### 🗑️ Municipios Eliminados
#
# Durante el proceso, se identificaron municipios con una elevada cantidad de valores ausentes. Para garantizar la fiabilidad del dataset, se eliminaron los siguientes municipios con más de 6 valores NaN:
#
# | Código | Municipio               |
# |--------|--------------------------|
# | 14901  | Fuente Carreteros        |
# | 14902  | Guijarrosa, La           |
# | 48916  | Usansolo                 |
# | 48915  | Ziortza-Bolibar          |
# | 18065  | Dehesas Viejas           |
# | 18915  | Domingo Pérez de Granada |
# | 18077  | Fornes                   |
# | 18106  | Játar                    |
# | 18916  | Torrenueva Costa         |
# | 18914  | Valderrubio              |
# | 6903   | Guadiana                 |
# | 11903  | San Martín del Tesorillo |
# | 15026  | Cesuras                  |
# | 15063  | Oza dos Ríos             |
# | 15902  | Oza-Cesuras              |
# | 29903  | Montecorto               |
# | 29904  | Serrato                  |
# | 29902  | Villanueva de la Concepción |
# | 36011  | Cerdedo                  |
# | 36902  | Cerdedo-Cotobade         |
# | 36012  | Cotobade                 |
# | 50903  | Villamayor de Gállego    |
# | 41904  | Palmar de Troya, El      |
# | 10903  | Alagón del Río           |
# | 10905  | Pueblonuevo de Miramontes |
# | 10904  | Tiétar                   |
# | 10902  | Vegaviana                |
# | 4904   | Balanegra                |
# | 43907  | Canonja, La              |
# | 38901  | Pinar de El Hierro, El   |
# | 21902  | Zarza-Perrunal, La       |
# | 46904  | Benicull de Xúquer       |
#
# > 🧼 *Estos municipios presentaban series temporales incompletas o inconsistentes.*
#
# ---
#
# ### ✅ Conclusiones
#
# - ✅ **Calidad garantizada:** Se han eliminado los valores faltantes mediante interpolación + técnicas de rellenado.
# - 🔍 **Tratamiento de outliers personalizado**, excluyendo vecinos también atípicos.
# - 📊 **Transformación estructural** del dataset que permite análisis temporales de forma directa.
#
# El dataset final `cifras_poblacion_municipio.csv` está listo para su uso en modelos, visualizaciones o simulaciones.
